# %%
# !python detect.py --source test1.jpg --weights runs/train/yolov7x/weights/best.pt
# Out:
# Namespace(weights=['runs/train/yolov7x/weights/best.pt'], source='test1.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 6337f40 torch 1.12.0+cu102 CUDA:0 (GeForce RTX 2060 SUPER, 7982.3125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /data/shared/methmal/PycharmProjects/YOLOv7_cutom_dataset/venv/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36907898 parameters, 6194944 gradients, 104.5 GFLOPS
# ...

# %%
# !python detect.py --source test1.jpg --weights yolov7.pt

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/detect/exp/test1.jpg', width=1000)
